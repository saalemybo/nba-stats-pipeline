# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Connect to the local SQLite database
conn = sqlite3.connect("../database/nba_stats.db")

# %%
# SQL query to get Curry's game-by-game stats
query = """
SELECT game_date, pts, ast, reb
FROM curry_game_logs
ORDER BY game_date;
"""

df = pd.read_sql_query(query, conn)
conn.close()

# Preview the data
df.head()
# Out:
#     game_date  pts  ast  reb
# 0  2023-10-24   27    1    5
# 1  2023-10-27   41    4    4
# 2  2023-10-29   24    6    7
# 3  2023-10-30   42    5    5
# 4  2023-11-01   21    3    5

# %%
# Convert game_date to datetime
df["game_date"] = pd.to_datetime(df["game_date"])

# Plot the data
plt.figure(figsize=(12, 6))
plt.plot(df["game_date"], df["pts"], marker="o", label="Points")
plt.plot(df["game_date"], df["ast"], marker="s", label="Assists")
plt.plot(df["game_date"], df["reb"], marker="^", label="Rebounds")

plt.title("Steph Curry - Game-by-Game Performance (2023-24)")
plt.xlabel("Game Date")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
